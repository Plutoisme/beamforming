# %% [markdown]
# #### 空间宽带声源定位测试
# 1. 该算法预用于俯仰角抑制后，希望能够在我们关注的区域内找到声源位置。
# 2. 测试包括单声源测试， 以及多声源测试。
# 3. 在多声源测试中，引入了一个语音源和噪声源，他们的长度都为4s， 以512个采样点为一帧(32ms),帧移128个采样点(延时8ms)。可以控制他们的总体信噪比， 但每一帧的信噪比不一样，有些帧中噪声能量会超过信号能量，这一部分还需要考虑一些额外处理。
# 4. 对于单声源测试， 测试效果非常稳定且准确。

# %%
from Beamform.BFModel import beamforming_model
from Beamform.CMA100 import CMA100
import librosa
from Beamform.tools import ConvertToTargetDb, CalRms, NormLength
import numpy as np
import IPython.display as ipd
import soundfile as sf

# %%
# 初始化cma100阵列
cma100 = CMA100(fs=32000, L=1024)
# 导入音频
audio_data, _ = librosa.load('./32k_demo/audio1.wav', sr=32000)
noise_data, _ = librosa.load('./32k_demo/audio2.wav', sr=32000)
audio_data = audio_data[:4*32000]
noise_data = noise_data[:4*32000]
# 控制声音能量
audio_data = ConvertToTargetDb(audio_data, -20)
noise_data = ConvertToTargetDb(noise_data, -30)
sf.write("./audio_data.wav", audio_data, samplerate=32000)
sf.write("./noise_data.wav", noise_data, samplerate=32000)

audio_rfft = librosa.stft(audio_data, n_fft=1024, win_length=1024, hop_length=256)
noise_rfft = librosa.stft(noise_data, n_fft=1024, win_length=1024, hop_length=256)

# %%
# 空间单信号源定位测试， 对单一信号源进行定位测试：
# 设置声源位置
audio_x = 3.0
audio_y = 0.0
audio_z = 0.0

# 模拟阵列流式接受信号， 并处理的过程
frameLength = 1024
N = audio_rfft.shape[1]
enhancedAudio = np.zeros_like(audio_rfft)
micAudio = np.zeros_like(audio_rfft)

# 流式处理：
for i in range(N):
    cma100.add_signal(S_x = audio_x, S_y = audio_y, S_z = audio_z, signal_rfft = audio_rfft[:, i])
    cma100.band_filter() # 频点分配
    cma100.angleFilter_doa() # 角度抑制 + doa
    cma100.reset() # 重置阵列，用于处理下一帧
# Out:
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0

# %%
# 空间单信号源定位测试， 对单一信号源进行定位测试：
# 设置声源位置
audio_x = 3.0
audio_y = 0.0
audio_z = 0.0

# 模拟阵列流式接受信号， 并处理的过程
frameLength = 512
N = audio_rfft.shape[1]
enhancedAudio = np.zeros_like(audio_rfft)
micAudio = np.zeros_like(audio_rfft)

# 流式处理：
for i in range(N):
    cma100.reset()
    cma100.add_signal(S_x = audio_x, S_y = audio_y, S_z = audio_z, signal_rfft = audio_rfft[:, i])
    cma100.band_filter() # 频点分配
    cma100.angleFilter_doa(bf_method = "music") # 角度抑制 + doa
    if i == 15:
        break
# Out:
# x is 0.0
# y is -0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      16 cma100.add_signal(S_x = audio_x, S_y = audio_y, S_z = audio_z, signal_rfft = audio_rfft[:, i])
#      17 cma100.band_filter() # 频点分配
# ---> 18 cma100.angleFilter_doa(bf_method = "music") # 角度抑制 + doa
#      19 if i == 15:
#      20     break
#
# File ~/project/Beamforming/Beamform/CMA100.py:248, in CMA100.angleFilter_doa(self, decay_angle, bf_method)
#     246                 P[k, :, :, angle_index] = self.doa_v2(k, theta_range, rou_range)
#     247             if bf_method == "music":
# --> 248                 P[k, :, :, angle_index] = self.doa_v3(k, theta_range, rou_range)
#     250 P_fullband = np.sum(P, axis=0, keepdims=False)
#     251 #print("P_fullband is", P_fullband)
#     252
#     253 # 找到P_fullband的极值点， 计算出声源位置
#
# File ~/project/Beamforming/Beamform/CMA100.py:318, in CMA100.doa_v3(self, k, theta_range, rou_range)
#     316 y = rou_range[i] * np.sin(theta_range[j])
#     317 distance_matrix = np.sqrt( (x - micx_matrix)**2 + (y - micy_matrix)**2 + (z-micz_matrix)**2 )
# --> 318 phase_matrix = np.exp(1j*2*np.pi*k*self.fs*distance_matrix/self.c/self.L)
#     319 phase_matrix_H = np.conj(phase_matrix.T)
#     320 P[i,j] = 1 / np.abs( np.dot(    np.dot(phase_matrix_H, En) , np.dot(np.conj(En).T, phase_matrix)    ))
#
# KeyboardInterrupt:

# %%
# 空间双信号源定位测试， 对能量较大的信号源进行定位测试：
# 设置声源位置
audio_x = 3.0
audio_y = 0.0
audio_z = 0.0

noise_x = -2.0
noise_y = 1.0
noise_z = 0.0

# 模拟阵列流式接受信号， 并处理的过程
frameLength = 1024
N = audio_rfft.shape[1]
enhancedAudio = np.zeros_like(audio_rfft)
micAudio = np.zeros_like(audio_rfft)


# 流式处理：
for i in range(N):
    cma100.add_signal(S_x = audio_x, S_y = audio_y, S_z = audio_z, signal_rfft = audio_rfft[:, i])
    cma100.add_signal(S_x = noise_x, S_y = noise_y, S_z = noise_z, signal_rfft = noise_rfft[:, i])
    micAudio[:,i] = cma100.build_signal_rfft(method=0) # 把处理前的信号提取出来
    cma100.band_filter() # 频点分配
    cma100.angleFilter_doa(bf_method="cbf") # 角度抑制
    #cma100.angleFilter_Beamform()
    #enhancedAudio[:,i] = cma100.build_signal_rfft(method=0) # 将处理后的信号提取出来
    cma100.reset() # 重置阵列，用于处理下一帧
# Out:
# x is -1.8874674972282504
# y is 0.9205794082570632
# x is -1.3244213892883898
# y is 0.7042073441788372
# x is 2.999543085469174
# y is 0.05235721931185061
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -2.1571057111180005
# y is 1.0520907522937866
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -0.9829824531467898
# y is 0.6882917236212561
# x is 2.499619237890978
# y is 0.04363101609320884
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.1
# y is 0.0
# x is 2.8000000000000003
# y is 0.0
# x is 2.2985989021439206
# y is 0.08026884241575222
# x is 1.793150456565142
# y is 0.15688033694578474
# x is 0.8457233587073176
# y is 0.30781812899310185
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.9000000000000004
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.8000000000000003
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.898233398355378
# y is 0.1012085404372528
# x is 3.3746569155804953
# y is 0.4143557675775015
# x is 5.219481090964703
# y is 0.9203353416347311
# x is 6.235968414625506
# y is 1.4396867478007362
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is 3.192204960831438
# y is 0.2232207159812011
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.2985989021439206
# y is 0.08026884241575222
# x is -0.3267834210090161
# y is 0.5032023407672547
# x is -0.4212705162064337
# y is 0.5590448570331051
# x is -0.9829824531467898
# y is 0.6882917236212561
# x is 0.027902589497650093
# y is 0.3990256201039297
# x is 0.013959798681000432
# y is 0.39975633080763834
# x is -0.5656854249492377
# y is 0.5656854249492383
# x is -0.9948450870660498
# y is 0.6710314841648968
# x is 0.9659258262890683
# y is 0.25881904510252074
# x is -0.6582183314572532
# y is 0.6137985240562489
# x is -1.285750951053168
# y is 0.7725571123650821
# x is 0.0
# y is -0.0
# x is -1.0902717383290508
# y is 0.7080307455195359
# x is -1.765895185717853
# y is 0.9389431255717829
# x is 0.0
# y is -0.0
# x is -1.3856406460551016
# y is 0.8000000000000006
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -2.1571057111180005
# y is 1.0520907522937866
# x is -1.765895185717853
# y is 0.9389431255717829
# x is -1.574315472850912
# y is 0.8726573164434076
# x is -1.7820130483767351
# y is 0.9079809994790946
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -2.0845079101842945
# y is 0.9720220020036099
# x is -1.9032463527769645
# y is 0.8874983496554698
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.8543677091335744
# y is 0.7492131868318253
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.899558315953535
# y is 0.05061197866812226
# x is 2.6995887769222566
# y is 0.04712149738066555
# x is -0.7187719590425634
# y is 0.5416335208368438
# x is -1.6776004264319606
# y is 0.8919959692931939
# x is -0.6688303429296545
# y is 0.6022175457229728
# x is -0.2630226880734463
# y is 0.5392764277795004
# x is 2.3985379848458304
# y is 0.08375879208600231
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.5996040074066173
# y is 0.045376256736937196
# x is 2.9000000000000004
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.8000000000000003
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is -1.6776004264319606
# y is 0.8919959692931939
# x is -1.7975880925983336
# y is 0.8767422935781554
# x is -2.1571057111180005
# y is 1.0520907522937866
# x is -2.1571057111180005
# y is 1.0520907522937866
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is 3.0
# y is 0.0
# x is 2.999543085469174
# y is 0.05235721931185061
# x is -2.3182219830937636
# y is 0.6211657082460516
# x is -2.0098000068137214
# y is 0.894820614766762
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -2.132522865503611
# y is 0.8615951648565991
# x is 3.7630186612179677
# y is 0.5288577836482486
# x is 3.098111563759197
# y is 0.10818843977775298
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 3.0
# y is 0.0
# x is -2.174692723878428
# y is 0.7488067552514621
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -2.0493150056332454
# y is 1.044178149400959
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -2.067226306488084
# y is 1.0082536376148787
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is -2.0493150056332454
# y is 1.044178149400959
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.4127161485742825
# y is 0.7511545004574264
# x is -0.565685424949238
# y is 0.5656854249492381
# x is 1.0625184089179753
# y is 0.2847009496127728
# x is 0.48296291314453416
# y is 0.12940952255126037
# x is 1.8927699263743167
# y is 0.16559591122055056
# x is 2.6995887769222566
# y is 0.04712149738066555
# x is 2.9000000000000004
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.899558315953535
# y is 0.05061197866812226
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.9000000000000004
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.097122022984605
# y is 0.10990550811018208
# x is 0.09659258262890684
# y is 0.025881904510252074
# x is 0.0
# y is -0.0
# x is 2.097122022984605
# y is 0.10990550811018208
# x is 0.0
# y is -0.0
# x is 0.0
# y is -0.0
# x is 0.0
# y is -0.0
# x is 0.0
# y is -0.0
# x is 2.1969849764600626
# y is 0.11513910373447647
# x is 1.9951281005196484
# y is 0.1395129474882507
# x is 2.899558315953535
# y is 0.05061197866812226
# x is 3.1
# y is 0.0
# x is 3.1
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.8000000000000003
# y is 0.0
# x is 2.499619237890978
# y is 0.04363101609320884
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.3985379848458304
# y is 0.08375879208600231
# x is 0.7308363661140808
# y is 0.3253893144606401
# x is -0.0069809625749133915
# y is 0.3999390780625565
# x is 0.0
# y is -0.0
# x is -0.565685424949238
# y is 0.5656854249492381
# x is -1.1872673346189961
# y is 0.7418869699264875
# x is -2.067226306488084
# y is 1.0082536376148787
# x is -2.0493150056332454
# y is 1.044178149400959
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.1143174909127456
# y is 0.6695494973830711
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.9000000000000004
# y is 0.0
# x is 2.598416150249649
# y is 0.09073869142650251
# x is 1.8927699263743167
# y is 0.16559591122055056
# x is 1.4815325108927067
# y is 0.23465169756034632
# x is 0.8693332436601615
# y is 0.23293714059226867
# x is 0.0
# y is -0.0
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.871113700795572
# y is 0.9533800494530493
# x is -0.8784990610520219
# y is 0.6619965254672535
# x is 2.596436790361892
# y is 0.13607348623165402
# x is 2.4984770675477392
# y is 0.08724874175625241
# x is 2.5996040074066173
# y is 0.045376256736937196
# x is 2.6995887769222566
# y is 0.04712149738066555
# x is 2.799573546437896
# y is 0.0488667380243939
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.999543085469174
# y is 0.05235721931185061
# x is 3.4808266337889564
# y is 0.36584962143678723
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.977346901858167
# y is 0.964416522935971
# x is -2.0098000068137214
# y is 0.894820614766762
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.977346901858167
# y is 0.964416522935971
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is 3.192204960831438
# y is 0.2232207159812011
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.098111563759197
# y is 0.10818843977775298
# x is -1.9938771314806296
# y is 0.9297601758295398
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042
# x is -1.9602143532144087
# y is 0.9987790994270042

# %%
# 空间双信号源定位测试， 对能量较大的信号源进行定位测试：
# 设置声源位置
audio_x = 3.0
audio_y = 0.0
audio_z = 0.0

noise_x = -2.0
noise_y = 1.0
noise_z = 0.0

# 模拟阵列流式接受信号， 并处理的过程
frameLength = 512
N = audio_rfft.shape[1]
enhancedAudio = np.zeros_like(audio_rfft)
micAudio = np.zeros_like(audio_rfft)


# 流式处理：
for i in range(N):
    cma100.add_signal(S_x = audio_x, S_y = audio_y, S_z = audio_z, signal_rfft = audio_rfft[:, i])
    cma100.add_signal(S_x = noise_x, S_y = noise_y, S_z = noise_z, signal_rfft = noise_rfft[:, i])
    micAudio[:,i] = cma100.build_signal_rfft(method=0) # 把处理前的信号提取出来
    cma100.band_filter() # 频点分配
    cma100.angleFilter_doa(bf_method="cbf") # 角度抑制
    #cma100.angleFilter_Beamform()
    #enhancedAudio[:,i] = cma100.build_signal_rfft(method=0) # 将处理后的信号提取出来
    cma100.reset() # 重置阵列，用于处理下一帧
    if i == 10: break
# Out:
# x is 0.0
# y is -0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 3.0
# y is 0.0
# x is 2.899558315953535
# y is 0.05061197866812226
# x is 2.9000000000000004
# y is 0.0
# x is 3.0
# y is 0.0
